# %%
class Vector:                     #Creación de la clase Vector 
    
    def __init__(self, x, y, z):  #Creación de las variables que tendrán lo vectores 
        
        self.x = x
        self.y = y
        self.z = z
        
    def __add__(self, v):         #Funciones para enseñar a la clase a hacer operaciones entre vectores 
        
        return Vector (self.x + v.x,self.y + v.y,self.z + v.z)
    
    def __sub__(self, v):
        
        return Vector (self.x - v.x,self.y - v.y,self.z - v.z)
    
    def __mul__(self,s):
        
        return Vector (self.x*s,self.y*s,self.z*s)
    
    
    def __truediv__(self,s):
        
        return Vector (self.x/s,self.y/s,self.z/s)
    
    def __str__(self):            #Función para imprimir vectores de una manera mejor 
        
        return '(%f, %f, %f)' % (self.x, self.y, self.z)
    
class Particula:                  #Creación de la clase partícula
    
    def __init__(self):           #_init_ para que al llamar la función llame a esta parte en específico
    
        self.p = Vector(0,0,0)    #Creación de los vectores de posición velocidad y fuerzas de cada partícula
        self.v = Vector(0,0,0)
        self.f = Vector(0,0,0)
        self.m = 0                #Definición de masa color y tamaño de partículas, el color se maneja en datos(RGB)
        self.color = (0,0,0)
        self.tam = 1
    
    def posicionP(self, pos):     #Funciones para que cada partícula tenga sus datos individuales
        
        self.p = pos
        
    def velocidadP(self, vel):
        
        self.v = vel
        
    def fuerzaP(self, fuerza):
        
        self.f = fuerza
        
    def masaP(self, masa):
        
        self.m = m
        
    def tamanioP(self, tam):
        
        self.tam = tam
        
    def colorP(self, color):
        
        self.color = color
        
    def kRestitucion(self, k):
        
        self.k = k
    
    def __str__(self):             #Funciones para que al imprimir las partículas se vea de manera correcta 
        
        return 'Posicion \t%s \nVelocidad \t%s \n' % (self.p,self.v)
    
    def __repr__(self):
        
        return 'Posicion \t%s \nVelocidad \t%s \n' % (self.p,self.v)
    
    def gParticula(self):

        r = self.tam
        a = linspace(0, 2*pi, int(r*5))
        b = linspace(0, pi, int(r*5))
        xc = self.p.x + r * outer(cos(a), sin(b))
        yc = self.p.y+0.3*r * outer(sin(a), sin(b))
        zc = self.p.z+r * outer(ones(size(a)), cos(b))
        
        return xc,yc,zc

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from numpy import sin, cos, pi, outer, ones, size, linspace
import numpy as np
from PIL import Image
import random

class ParticulasAleatoriasE:          #Creación de la clase para realizar el arreglo de partículas aleatorias 
    
    def __init__(self, n):           #Arreglo de n partículas con tiempo = 0, gravedad = 9.8, constante = 0.8 y paso = 0.5 
                                     #Self para que cada partícula tenga sus variables individuales 
        self.particulas = []
        self.n = n
        self.t = 0
        self.gravedad = -9.8
        self.paso = 0.5
        
        for i in range(0,int(n)):    #Añadir las partículas creadas al arreglo (.append)
            
            par = Particula()
            self.particulas.append(par)
            #print(self.particulas)
     
    def CreacionAleatoriaE(self):     #Creación de las variables aleatorias para cada partícula
        
        count = 0
        
        for part in self.particulas: #For(part) para que este ciclo pase por todo el arreglo dando las variables a cada partícula
            
            t = random.randint(1, 5) #Tiempo random para cada partícula
            color = (random.random(), random.random(), random.random()) #random para generar valores entre 0 y 1 para los valores de rgb
            part.colorP(color)
            part.velocidadP(Vector(0, 0, 0))
            part.m = 100
            
            count = count + 1        #Velocidades iniciales hacia 4 direcciones diferentes
                                     #Se utilizaron 100 partículas ya que 1000 eran muchas para el equipo
            if(count == 1):
                
                part.kRestitucion = 0.8
                part.posicionP(Vector(10, 100, 10))
                part.velocidadP(Vector(0, 0, 0))
                part.tamanioP(8)
                
            if(count == 2):
            
                part.kRestitucion = 0.5
                part.posicionP(Vector(-10, 100, -10))
                part.velocidadP(Vector(0, 0, 0))
                part.tamanioP(5)
                
            if(count == 3):
                
                part.kRestitucion = 0
                part.posicionP(Vector(20, 100, -20))
                part.velocidadP(Vector(0, 0, 0))
                part.tamanioP(3)
                

    def Euler(self, n):               #Método de Euler 
                 
        for part in self.particulas:
            
            part.p = part.p + self.dpE(self.t, part.p, part.v)*self.paso 
            part.v = part.v + self.dvE(self.t, part.p,part.v, part.m)*self.paso 
            y=part.p.y
            
            if(y <= 0): 
                
                part.v.y = -part.kRestitucion*part.v.y 
        
        self.t = self.t + paso
        self.GraficarE(n)
        
    def SimularE(self, duracion,paso):
        
        self.paso = paso
        frames = int(((duracion)/paso) + 1)
        self.t = 0;
        self.GraficarE(0)               #Grafica t = 0
        
        print('Cuadro ' + str(0) + ' Finalizado')
        
        for n in range(1, frames):
            
            self.Euler(n)
            print('Cuadro ' + str(n) + ' Finalizado')
        
        images = [Image.open(f"SecuenciaEuler1{n}.png") for n in range(frames)]
        images[0].save('SecuenciaEuler1Final.gif', save_all = True, append_images = images[1:], duration = 100, loop = 0)
        
        print('Terminé')
            
    def GraficarE(self, n):
    
        fig = plt.figure(figsize = (10, 10))
        ax = fig.add_subplot(1, 1, 1, projection = '3d')            
        
        for part in self.particulas:   #Ciclo para graficar todas las portículas 
            
            x,y,z = part.gParticula()  
            ax.plot_surface(x, z, y, color = part.color, shade = True)
    
        ax.set_xlim(-100, 100)
        ax.set_ylim(-100, 100)
        ax.set_zlim(0, 100)
        plt.title("t = " + str(round(self.t, 2)))
        plt.savefig(f"SecuenciaEuler1{n}.png")
        plt.close()
        
    def fuerzaGravedadE(self, m):
        
        return (Vector(0, m*self.gravedad, 0))
    
    def fuerzaE(self, t, p, v, m):
        
        ftotal = self.fuerzaGravedadE(m) #Sumatoria de fuerzas
        
        return ftotal
        
    def dvE(self, t, p, v, m) :
        
        return self.fuerzaE(t, p, v, m)/float(m)
    
    def dpE(self, t, p, v) :        
        
        return v

# %%
S = ParticulasAleatoriasE(3)
S.CreacionAleatoriaE()
duracion = 10
paso = 0.5
S.SimularE(duracion, paso)
# Out:
# Cuadro 0 Finalizado
# Cuadro 1 Finalizado
# Cuadro 2 Finalizado
# Cuadro 3 Finalizado
# Cuadro 4 Finalizado
# Cuadro 5 Finalizado
# Cuadro 6 Finalizado
# Cuadro 7 Finalizado
# Cuadro 8 Finalizado
# Cuadro 9 Finalizado
# Cuadro 10 Finalizado
# Cuadro 11 Finalizado
# Cuadro 12 Finalizado
# Cuadro 13 Finalizado
# Cuadro 14 Finalizado
# Cuadro 15 Finalizado
# Cuadro 16 Finalizado
# Cuadro 17 Finalizado
# Cuadro 18 Finalizado
# Cuadro 19 Finalizado
# Cuadro 20 Finalizado
# Terminé

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from numpy import sin, cos, pi, outer, ones, size, linspace
import numpy as np
from PIL import Image
import random

class ParticulasAleatoriasE:          #Creación de la clase para realizar el arreglo de partículas aleatorias 
    
    def __init__(self, n):           #Arreglo de n partículas con tiempo = 0, gravedad = 9.8, constante = 0.8 y paso = 0.5 
                                     #Self para que cada partícula tenga sus variables individuales 
        self.particulas = []
        self.n = n
        self.t = 0
        self.gravedad = -9.8
        self.paso = 0.5
        
        for i in range(0,int(n)):    #Añadir las partículas creadas al arreglo (.append)
            
            par = Particula()
            self.particulas.append(par)
            #print(self.particulas)
     
    def CreacionAleatoriaE(self):     #Creación de las variables aleatorias para cada partícula
        
        count = 0
        
        for part in self.particulas: #For(part) para que este ciclo pase por todo el arreglo dando las variables a cada partícula
            
            t = random.randint(1, 5) #Tiempo random para cada partícula
            color = (random.random(), random.random(), random.random()) #random para generar valores entre 0 y 1 para los valores de rgb
            part.colorP(color)
            part.velocidadP(Vector(0, 0, 0))
            part.m = 100
            
            count = count + 1        #Velocidades iniciales hacia 4 direcciones diferentes
                                     #Se utilizaron 100 partículas ya que 1000 eran muchas para el equipo
            if(count == 1):
                
                part.kRestitucion = 1
                part.posicionP(Vector(-100, 0, 80))
                part.velocidadP(Vector(50, 30, 0))
                part.tamanioP(8)
                
            if(count == 2):
            
                part.kRestitucion = 0.5
                part.posicionP(Vector(-100, 0, 60))
                part.velocidadP(Vector(40, 30, 0))
                part.tamanioP(5)
                
            if(count == 3):
                
                part.kRestitucion = 0
                part.posicionP(Vector(-100, 0, 20))
                part.velocidadP(Vector(50, 25, 0))
                part.tamanioP(3)
                

    def Euler(self, n):               #Método de Euler 
                 
        for part in self.particulas:
            
            part.p = part.p + self.dpE(self.t, part.p, part.v)*self.paso 
            part.v = part.v + self.dvE(self.t, part.p,part.v, part.m)*self.paso 
            y=part.p.y
            
            if(y <= 0): 
                
                part.v.y = -part.kRestitucion*part.v.y 
        
        self.t = self.t + paso
        self.GraficarE(n)
        
    def SimularE(self, duracion,paso):
        
        self.paso = paso
        frames = int(((duracion)/paso) + 1)
        self.t = 0;
        self.GraficarE(0)               #Grafica t = 0
        
        print('Cuadro ' + str(0) + ' Finalizado')
        
        for n in range(1, frames):
            
            self.Euler(n)
            print('Cuadro ' + str(n) + ' Finalizado')
        
        images = [Image.open(f"SecuenciaEuler1{n}.png") for n in range(frames)]
        images[0].save('SecuenciaEuler1Final.gif', save_all = True, append_images = images[1:], duration = 100, loop = 0)
        
        print('Terminé')
            
    def GraficarE(self, n):
    
        fig = plt.figure(figsize = (10, 10))
        ax = fig.add_subplot(1, 1, 1, projection = '3d')            
        
        for part in self.particulas:   #Ciclo para graficar todas las portículas 
            
            x,y,z = part.gParticula()  
            ax.plot_surface(x, z, y, color = part.color, shade = True)
    
        ax.set_xlim(-100, 1000)
        ax.set_ylim(0, 400)
        ax.set_zlim(0, 100)
        plt.title("t = " + str(round(self.t, 2)))
        plt.savefig(f"SecuenciaEuler1{n}.png")
        plt.close()
        
    def fuerzaGravedadE(self, m):
        
        return (Vector(0, m*self.gravedad, 0))
    
    def fuerzaE(self, t, p, v, m):
        
        ftotal = self.fuerzaGravedadE(m) #Sumatoria de fuerzas
        
        return ftotal
        
    def dvE(self, t, p, v, m) :
        
        return self.fuerzaE(t, p, v, m)/float(m)
    
    def dpE(self, t, p, v) :        
        
        return v

# %%
S = ParticulasAleatoriasE(4)
S.CreacionAleatoriaE()
duracion = 10
paso = 0.5
S.SimularE(duracion, paso)
# Out:
# Cuadro 0 Finalizado
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2780/1951098049.py in <module>
#       3 duracion = 10
#       4 paso = 0.5
# ----> 5 S.SimularE(duracion, paso)
#
# ~\AppData\Local\Temp/ipykernel_2780/2517906287.py in SimularE(self, duracion, paso)
#      84         for n in range(1, frames):
#      85
# ---> 86             self.Euler(n)
#      87             print('Cuadro ' + str(n) + ' Finalizado')
#      88
#
# ~\AppData\Local\Temp/ipykernel_2780/2517906287.py in Euler(self, n)
#      68             if(y <= 0):
#      69
# ---> 70                 part.v.y = -part.kRestitucion*part.v.y
#      71
#      72         self.t = self.t + paso
#
# TypeError: bad operand type for unary -: 'method'
